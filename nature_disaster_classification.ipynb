# %% [markdown]
# ## Data import

# %%
import pandas as pd
from tqdm import tqdm
import os

import re
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer

nltk.download('punkt')
nltk.download('stopwords')

pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_classes = pd.read_csv('/content/drive/MyDrive/HSE_project/events_with_KNY.csv')
df_classes_new =  pd.DataFrame()
df_classes
# Out:
#                            Опасные природные процессы  \
# 0                              Абразия и термоабразия
# 1              Переработка берегов водохранилищ, озер
# 2                                               Карст
# 3                                            Суффозия
# 4                        Просадочность лессовых пород
# 5        Подтопление территории, переувлажнение почвы
# 6                       Эрозия плоскостная и овражная
# 7                                 Русловые деформации
# 8                                Термоэрозия овражная
# 9                     Термокарст, деградация мерзлоты
# 10                                            Пучение
# 11                                        Солифлюкция
# 12                                  Наледеобразование
# 13                                         Наводнение
# 14                     Ураганы, смерчи, сильный ветер
# 15                                               Жара
# 16                                             Засуха
# 17                                          Заморозки
# 18                                               Град
# 19                         Сильные атмосферные осадки
# 20                         Пожарная опасность в лесах
# 21                                             Лавины
# 22                                               Сели
# 23                             Оползни, осыпи, обвалы
# 24                                       Пыльная буря
# 25                      Гололедно-изморозевые явления
# 26                          Аномально холодная погода
# 27                        Резкие перепады температуры
# 28  Туман, мгла, условия медленного рассеивания за...
# 29    Вредители и болезни лесов и сельского хозяйства
# 30                                                КНЯ
#
#                     Описание явления простыми словами  \
# 0   Размыв и отступание берега моря. Обычно происх...
# 1   Изменение линии берега, выполняемое другими пр...
# 2   Некоторые горные породы растворяются водой, ка...
# 3   В горных породах, состоящих из больших и мален...
# 4   Лессовая горная порода, при смачивании, может ...
# 5   Когда вода не может уходит в землю и/или утека...
# 6   Вынос (смыв) частичек грунта с поверхности вод...
# 7   Берега, острова и судовые фарватеры некоторых ...
# 8   Как эрозия, только в условиях мерзлоты. При та...
# 9   При протаивании мерзлоты (т.е. вытаивании част...
# 10  При замерзании воды она расширяется. Замерзани...
# 11  В ситуации долгого чередования промерзания/отт...
# 12  При вытекании зимой воды (подземные источники,...
# 13  Воды в реке становится так много, что она выхо...
# 14  Ветры сильнее 10 м/с (39км/ч), обычно с еще бо...
# 15  Долгий период нехарактерно высоких температур,...
# 16  Продолжительная нехватка воды; не обязательно,...
# 17  Понижение температуры ниже 0 °С ночью на фоне ...
# 18  Осадки в виде ледяных гранул, иногда величиной...
# 19  Очень сильные дождь/снег. Обычно, с нетипично ...
# 20  Жаркая и/или сухая погода приводит лес в состо...
# 21  Сход снега вниз по склону. Может быть как в ви...
# 22  Сход вниз по водотоку водо-грязе-каменной масс...
# 23  Быстрое или медленное движение части материала...
# 24  Сильный ветер, несущий частички грунта. Во вре...
# 25  Намерзание из воздуха или из-за осадков слоя л...
# 26  Гораздо более холодные температуры, чем типичн...
# 27  Перепады среднесуточной температуры более 3 гр...
# 28  Комплекс метеорологических условий и из послед...
# 29  В результате неблагоприятной погоды древостой ...
# 30  Сочетание нескольких природных явлений: сильны...
#
#                    Простые словосочетания для явления  \
# 0   отступание берега; разрушение берега; берегова...
# 1   отступание берега; разрушение берега; берегова...
# 2   появилась дыра; появилась яма; появился провал...
# 3   появилась дыра; появилась яма; появился провал...
# 4          Просадка, лесс просел, провал поверхности,
# 5   Затопило; стоит вода; половодье; паводок; подн...
# 6   Вырос овраг; край оврага обрушился; дорогу раз...
# 7   Изменился фарватер; мель; плес; меандры; перек...
# 8   Вырос овраг; край оврага обрушился; дорогу раз...
# 9   протаивание подземного льда, вытаивание ледяно...
# 10           Выпучило сваи; появились, выросли бугры;
# 11  течение грунта; стекание земли по склону; терр...
# 12  Вода разлилась и замерзла; оторвалась сосулька...
# 13  Половодье; паводок; затопило; ушло под воду; в...
# 14  Сильный ветер с порывами; шторм; шквал; буря; ...
# 15  Аномально высокая температура; волна жары; ост...
# 16                                                NaN
# 17  Холода вернулись; ночью и утром температура оп...
# 18  Ледяная крупа; величиной с орех; величиной с к...
# 19  Ливень; сильный дождь/снег; снежный ливень; сн...
# 20  Лесной пожар распространился...; низовой пожар...
# 21  Сход снега; мокрая лавина; сухая лавина; перио...
# 22  Грязевой поток; грязе-каменный поток; селевые ...
# 23       Обрушилась скала; сполз склон; земля съехала
# 24  Песчаная буря; ветер поднял пыль; черное небо;...
# 25  лед намерз на *объектах*; скользко на дорогах;...
# 26  Экстремальные холода; минимум температуы; холо...
# 27  Неустойчивая атмосфера; резкий рост (падение) ...
# 28                Загазованность; Снижение видимости;
# 29  Вспышка вередителей; распространение гнилей; о...
# 30                                                NaN
#
#    Простые словосочетания для триггеров или последствий  \
# 0   после шторма; высокие волны; *объект* упал в в...
# 1   *объект* упал в воду; *объект* пришлось перено...
# 2   Провалился под землю; просел грунт; продолжите...
# 3   Провалился под землю; просел грунт; продолжите...
# 4   Провалился под землю; просел грунт; продолжите...
# 5   Прошел ливень; стаивает снег; переувлажнение п...
# 6   Смыло плодородный слой; *объект* на краю овраг...
# 7   Уровень воды снизился; размыло берег; сильный ...
# 8                                      тает мерзлота;
# 9   тает мерзлота; после строительства; деформиров...
# 10                              Мерзлота; деформации;
# 11  вязко-пластическое течение; кровля мерзлоты; о...
# 12  Прорыв трубопровода; аномальные морозы; наруше...
# 13  площадь затопления; подтоплено; по городу пере...
# 14        сдуло; сорвало; повалило деревья; непогода;
# 15  плавится асфальт; увеличилось чило вызовов ско...
# 16  Уровень воды снизился до критического; погиб у...
# 17  иней; лед; пострадали посевы; вымерзли; во вре...
# 18  ливни; жара; пострадали посевы; пробоины в кро...
# 19  не справляется ливневка; затопило под мостом; ...
# 20  Жара; сгорело; пройденная огнем площадь; класс...
# 21  Снегом завалило; разрушило здание; погребло ту...
# 22  Смыло *объект*; снесло *объект*; погребло под ...
# 23  После продолжительных дождей; завалило дорогу;...
# 24  видимость сократилась;концентрация частиц прев...
# 25  под тяжестью оборвались провода; отключения эл...
# 26  Отопление не справляется; замерзли трубы; отме...
# 27  Увеличилось число вызовов скорой; коммунальные...
# 28  отменены рейсы; не рекомендуют выезжать на дор...
# 29  Погибли посевы (леса) на площади ... га; рой н...
# 30                                                NaN
#
#    Потенциальное неразличение авторами новостей внутри группы явлений
# 0                                                   А
# 1                                                   А
# 2                                                   Б
# 3                                                   Б
# 4                                                   Б
# 5                                                   С
# 6                                                   Д
# 7                                                   Д
# 8                                                   Д
# 9                                                   Б
# 10                                                  Б
# 11                                                  Е
# 12                                                NaN
# 13                                                  С
# 14                                                  Ф
# 15                                                  Ж
# 16                                                  Ж
# 17                                                  Ш
# 18                                                  И
# 19                                                  Ф
# 20                                                  Ж
# 21                                                  К
# 22                                                  Е
# 23                                                  Е
# 24                                                  Ф
# 25                                                  Ф
# 26                                                  Ш
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN

# %%
df_classes_new[['classes','description']] = df_classes[['Опасные природные процессы','Описание явления простыми словами']]
classes_list = ';'.join(df_classes_new['classes'].tolist())
classes_list = [f"{row[1]}: {row[2]}" for row in df_classes_new.itertuples()]

paths = ['/content/drive/MyDrive/HSE_project/СКФО/all_publics_SKFO/public_data_chechnya',
         '/content/drive/MyDrive/HSE_project/СКФО/all_publics_SKFO/public_data_dgstn',
         '/content/drive/MyDrive/HSE_project/СКФО/all_publics_SKFO/public_data_ingnsh',
         '/content/drive/MyDrive/HSE_project/СКФО/all_publics_SKFO/public_data_kbr',
         '/content/drive/MyDrive/HSE_project/СКФО/all_publics_SKFO/public_data_kcr',
         '/content/drive/MyDrive/HSE_project/СКФО/all_publics_SKFO/public_data_rso-alania',
         '/content/drive/MyDrive/HSE_project/СКФО/all_publics_SKFO/public_data_stvr',
          ]
objects = []
for path in paths:
    objects.extend(os.listdir(path))
objects
# Out:
# ['emergency_20_ramzan.csv',
#  'emergency_20_chr.csv',
#  'emergency_20_nauradmchr.csv',
#  'emergency_20_urusadm.csv',
#  'emergency_20_merargun.csv',
#  'emergency_20_public219691536.csv',
#  'emergency_20_public219650764.csv',
#  'emergency_20_grozadm.csv',
#  'emergency_20_gudad.csv',
#  'emergency_20_public217042926.csv',
#  'emergency_20_spitum.csv',
#  'emergency_20_akmr95.csv',
#  'emergency_20_nozhayurt.csv',
#  'emergency_20_public219610386.csv',
#  'emergency_20_public217777720.csv',
#  'emergency_20_shaligl.csv',
#  'emergency_20_shelkadm.csv',
#  'emergency_20_club222539909.csv',
#  'emergency_05_respublica_dagestan.csv',
#  'emergency_05_s.a.melikov.csv',
#  'emergency_05_vesti_novolak.csv',
#  'emergency_05_ognidagestanskie.csv',
#  'emergency_05_izbadm.csv',
#  'emergency_05_public205075193.csv',
#  'emergency_05_public209064868.csv',
#  'emergency_05_gorodkizlyar.csv',
#  'emergency_05_go.hasavyurt.csv',
#  'emergency_05_goyuzhnosukhokumsk.csv',
#  'emergency_05_public205278396.csv',
#  'emergency_05_public215536775.csv',
#  'emergency_05_mrahvahrayon.csv',
#  'emergency_05_akhtcakh.csv',
#  'emergency_05_mrbabayurtovskiyrayon.csv',
#  'emergency_05_botlikh_rayon_official.csv',
#  'emergency_05_mo_gergebil.csv',
#  'emergency_05_club205133241.csv',
#  'emergency_05_dokuz_para.csv',
#  'emergency_05_kazbekovskyrayon.csv',
#  'emergency_05_public204993037.csv',
#  'emergency_05_kay_rayon.csv',
#  'emergency_05_public204112973.csv',
#  'emergency_05_mo_kulirayon.csv',
#  'emergency_05_public216962289.csv',
#  'emergency_05_club204301538.csv',
#  'emergency_05_public205356315.csv',
#  'emergency_05_probekenez.csv',
#  'emergency_05_mokorkmaskala.csv',
#  'vk.barkov.net-wallposts-2024-06-27_12-08-46.csv',
#  'emergency_05_mr_magaramkentskiy_rayon.csv',
#  'emergency_05_nogayrayon2007.csv',
#  'emergency_05_rutulskiyraion_groups.csv',
#  'emergency_05_club80893614.csv',
#  'emergency_05_public210999281.csv',
#  'emergency_05_public205256846.csv',
#  'emergency_05_public205275614.csv',
#  'emergency_05_tarumraion.csv',
#  'emergency_05_mr.tlyarata.csv',
#  'emergency_05_uncukulskyraion.csv',
#  'emergency_05_public205276673.csv',
#  'emergency_05_mo.khivskiy.csv',
#  'emergency_05_khunzakh_ru.csv',
#  'emergency_05_public207832177.csv',
#  'emergency_05_cuntaru.csv',
#  'emergency_05_mo_charodinskiy.csv',
#  'emergency_05_gorodmakhachkala.csv',
#  'emergency_05_derbentadm.csv',
#  'emergency_05_public205272794.csv',
#  'emergency_05_gorod_buynaksk.csv',
#  'emergency_06_kalimatovmm?from=search.csv',
#  'emergency_06_ingushetia_gov.csv',
#  'emergency_06_public211287199.csv',
#  'emergency_06_nazran_rayon.csv',
#  'emergency_06_public213848763.csv',
#  'emergency_06_public205890039.csv',
#  'emergency_06_meriya_malgobeka.csv',
#  'emergency_06_club211640462.csv',
#  'emergency_06_magasadm.csv',
#  'emergency_06_public206020601.csv',
#  'emergency_06_public213970706.csv',
#  'emergency_07_kazbek_kokov.csv',
#  'emergency_07_propravitelstvokbr.csv',
#  'emergency_07_public216450325.csv',
#  'emergency_07_may_adm07region.csv',
#  'emergency_07_public216617739.csv',
#  'emergency_07_baksraion_adm07region.csv',
#  'emergency_07_public216603543.csv',
#  'emergency_07_prohladniy_adm07region.csv',
#  'emergency_07_kashkhatau_adm.csv',
#  'emergency_07_public211370116.csv',
#  'emergency_07_gp_chegem.csv',
#  'emergency_07_tyrnyauz34.csv',
#  'emergency_07_nalchik_adm07region.csv',
#  'emergency_07_baksan_adm07region.csv',
#  'emergency_09_rashidtemrezov.csv',
#  'emergency_09_pravitelstvo_kchr.csv',
#  'emergency_09_public210713273.csv',
#  'emergency_09_adige_hablsp.csv',
#  'emergency_09_public210721952.csv',
#  'emergency_09_karachaevsk_adm.csv',
#  'emergency_09_public214583457.csv',
#  'emergency_09_public217717670.csv',
#  'emergency_09_public210713652.csv',
#  'emergency_09_public216946616.csv',
#  'emergency_09_public211432321.csv',
#  'emergency_09_public210700779.csv',
#  'emergency_09_citycherkessk1825.csv',
#  'emergency_15_sergey.meniaylo.csv',
#  'emergency_15_alania_gov_ru.csv',
#  'emergency_15_amsardon.csv',
#  'emergency_15_gorsovetdgp.csv',
#  'emergency_15_gorodalagir.csv',
#  'emergency_15_public219287676.csv',
#  'emergency_15_public217593651.csv',
#  'emergency_15_amsmozdok.csv',
#  'emergency_15_ams_beslan.csv',
#  'emergency_15_club224356900.csv',
#  'emergency_15_amsvldz.csv',
#  'emergency_26_vladimirvladimirov5807.csv',
#  'emergency_26_stav_region.csv',
#  'emergency_26_zeleznovodskoff.csv',
#  'emergency_26_arzgir26adm.csv',
#  'emergency_26_abmr_vk.csv',
#  'emergency_26_levmosk.csv',
#  'emergency_26_novosel26adm.csv',
#  'emergency_26_predgorray.csv',
#  'emergency_26_stepnovskiy26adm.csv',
#  'emergency_26_geog26dm.csv',
#  'emergency_26_alex26adm.csv',
#  'emergency_26_androp26adm.csv',
#  'emergency_26_apanasenko26adm.csv',
#  'emergency_26_grach26adm.csv',
#  'emergency_26_essentukiofficial.csv',
#  'emergency_26_kochub26adm.csv',
#  'emergency_26_krasnogvardadm.csv',
#  'emergency_26_kurskiy26adm.csv',
#  'emergency_26_trunmo.csv',
#  'emergency_26_turkmenskiy26adm.csv',
#  'emergency_26_shpakray.csv',
#  'emergency_26_stavadm1777.csv',
#  'emergency_26_abgosk.csv',
#  'emergency_26_httpsizobilnenskijr07.gosweb.csv',
#  'emergency_26_neftgo.csv',
#  'emergency_26_ipatovo_okrug.csv',
#  'emergency_26_kislovodsk.official.csv',
#  'emergency_26_sovetmo26.csv',
#  'emergency_26_akmrsk.csv',
#  'emergency_26_lerm_adm.csv',
#  'emergency_26_minvodygorod.csv',
#  'emergency_26_nevadm.csv',
#  'emergency_26_novolgo.csv',
#  'emergency_26_pyatigorsk_official.csv',
#  'emergency_26_svetlogorskonline39.csv']

# %%
dfs = []
for path in paths:
    # Получаем список CSV файлов в текущей папке
    csv_files = [
        f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f)) and f.endswith(".csv")
    ]

    # Читаем каждый CSV файл и добавляем его в список DataFrame
    for f in csv_files:
        file_path = os.path.join(path, f)
        # Попробуем прочитать файл с разными разделителями
        try:
            df = pd.read_csv(file_path)
        except pd.errors.ParserError:
            try:
                df = pd.read_csv(file_path, sep=';')
            except pd.errors.ParserError:
                try:
                    df = pd.read_csv(file_path, sep=';', on_bad_lines='skip')
                except pd.errors.ParserError:
                    print(f"Error reading {file_path}. File will be skipped.")
                    continue
        dfs.append(df)

# Объединяем все DataFrame в один
df = pd.concat(dfs, ignore_index=True)
# Out:
# <ipython-input-16-e32e798b2d0d>:17: DtypeWarning: Columns (6,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep=';')

# %%
df
# Out:
#                               ССЫЛКА НА ПОСТ НАЗВАНИЕ ВЛАДЕЛЬЦА  \
# 0       https://vk.com/wall-106849164_174092       Город Москва
# 1       https://vk.com/wall-106849164_174088       Город Москва
# 2       https://vk.com/wall-106849164_174086       Город Москва
# 3       https://vk.com/wall-106849164_174083       Город Москва
# 4       https://vk.com/wall-106849164_174082       Город Москва
# ...                                      ...                ...
# 126182      https://vk.com/wall-169705869_10   Москва • Новости
# 126183       https://vk.com/wall-169705869_9   Москва • Новости
# 126184       https://vk.com/wall-169705869_8   Москва • Новости
# 126185       https://vk.com/wall-169705869_7   Москва • Новости
# 2       https://sun9-32.userapi.com/impg/_-vVzWeGcCONB...      12         4
# 3       https://sun9-5.userapi.com/impg/KsZbD2_CYq9u3Y...       8         1
# 4       https://sun9-20.userapi.com/impg/4dZeI5xS9yxTh...      25         7
# ...                                                   ...     ...       ...
# 126182  https://sun9-38.userapi.com/s/v1/if1/zzCqHxW8G...       0         0
# 126183  https://sun9-24.userapi.com/s/v1/if1/l6Ezv8e-y...       0         0
# 126184  https://sun9-21.userapi.com/s/v1/if1/cL89WZVPe...       0         0
# 126185  https://sun9-60.userapi.com/s/v1/if1/3YenQ3nv8...       1         1
# 126186  https://sun9-23.userapi.com/s/v1/if1/_gxXl4RwY...       0         0
#
#         КОММЕНТАРИЕВ  ПРОСМОТРОВ ИСТОЧНИК НАЗВАНИЕ ИСТОЧНИКА  \
# 0                  0         876      NaN                NaN
# 1                  1         927      NaN                NaN
# 2                  1        1254      NaN                NaN
# 3                  0        1297      NaN                NaN
# 4                  1        6548      NaN                NaN
# ...              ...         ...      ...                ...
# 126182             0          43      NaN                NaN
# 126183             0           6      NaN                NaN
# 126184             0          21      NaN                NaN
# 126185             0           6      NaN                NaN
# 126186             0           6      NaN                NaN
#
#                                  ССЫЛКА НА ВИДЕО ДОКУМЕНТЫ
# 0       https://vk.com/video-106849164_456242883       NaN
# 1                                            NaN       NaN
# 2                                            NaN       NaN
# 3                                            NaN       NaN
# 4                                            NaN       NaN
# ...                                          ...       ...
# 126182                                       NaN       NaN
# 126183                                       NaN       NaN
# 126184                                       NaN       NaN
# 126185                                       NaN       NaN
# 126186                                       NaN       NaN
#
# [126187 rows x 19 columns]

# %% [markdown]
# ## Filtering by key word

# %%
natural_disaster_words = []
with open('natural_disaster_words.txt', 'r', encoding='utf-8') as file:
  for line in file:
    natural_disaster_words.append(line.strip())

# %%
def normalize_text(text):
  text = str(text)
  # Приведение к нижнему регистру
  text = text.lower()

  # Удаление знаков препинания
  text = re.sub(r'[^\w\s]', '', text)

  # Удаление стоп-слов
  words = word_tokenize(text)
  stop_words = set(stopwords.words('russian'))
  words = [word for word in words if word not in stop_words]
  text = ' '.join(words)

  stemmer = SnowballStemmer("russian")
  words = word_tokenize(text)
  stemmed_words = [stemmer.stem(word) for word in words]
  normalized_text = ' '.join(stemmed_words)

  return normalized_text

# Применяем нормализацию к списку ключевых слов (по словосочетаниям)
normalized_keywords = []
for keywords in natural_disaster_words:
    normalized_keywords.append(normalize_text(keywords))

# Выводим нормализованный список ключевых слов
print(normalized_keywords)
# Out:
# ['отступан берег', 'разрушен берег', 'берегов эроз', 'размыван берег', 'шторм', 'высок волн', 'упа вод', 'разруш', 'смыл', 'берег мор', 'отступан берег', 'разрушен берег', 'берегов эроз', 'размыван берег', 'лин вод отступ', 'берег сошел оползен', 'абраз', 'упа вод', 'пришл перенос', 'судн причал', 'появ пляж', 'исчез пляж', 'берег озер', 'берег водохранилищ', 'появ дыр', 'появ ям', 'появ прова', 'просел част', 'провал земл', 'подземн вод разм земл', 'прова', 'воронк', 'пещер', 'полост провал земл', 'просел грунт', 'продолжительн ливн', 'сильн ливн', 'появ дыр', 'появ ям', 'появ прова', 'просел част', 'объект провал земл', 'подземн вод разм земл', 'провал земл', 'просел грунт', 'продолжительн ливн', 'сильн ливн', 'просадк', 'лесс просел', 'прова поверхн', 'провал земл', 'просел грунт', 'продолжительн ливн', 'сильн ливн', 'затоп', 'сто вод', 'половод', 'паводок', 'подня грунтов вод', 'прошел ливен', 'стаива снег', 'переувлажнен почв', 'погибл культур', 'погибл посев площад', 'вырос овраг', 'кра овраг обруш', 'дорог разм глубок рвом', 'пол смыл земл', 'cмыл плодородн сло', 'кра овраг упа', 'покос', 'измен фарватер', 'плес', 'меандр', 'перекат', 'измен русл уровен вод сниз', 'разм берег', 'сильн паводок', 'вырос овраг', 'кра овраг обруш', 'дорог разм глубок рвом тает мерзлот', 'протаиван подземн льда', 'вытаиван ледян залеж', 'ледян масс', 'просадк', 'осадк', 'сто вод', 'нача заболачиван', 'просел земл', 'протая земл', 'повыс температур пород', 'увелич глубин оттаиван', 'протая грунт тает мерзлот', 'деформирова', 'трещин дорожн полотн', 'обр лин электропередач', 'пор трубопровод', 'нефтепровод', 'газопровод', 'сниз несущ способн сва', 'фундамент', 'грунт основан потеря несущ способн', 'выпуч сва', 'выросл бугр', 'мерзлот', 'деформац', 'течен грунт', 'стекан земл склон', 'террас', 'обр дернин', 'трещин склон вязкопластическ течен', 'кровл мерзлот', 'оттаиван замерзан', 'вод разл замерзл', 'оторва сосуляоторва сосульк', 'прор трубопровод', 'аномальн мороз', 'наруш теплоизоляц', 'открыва двер', 'перекрыт дорог', 'сход налед крыш', 'налед упа голов', 'произошел сход налед', 'сосульк', 'половод', 'паводок', 'затоп', 'ушл вод', 'вод прибыва', 'уровен вод достиг отметк', 'уровен вод подня', 'вод сто', 'площад затоплен', 'подтопл', 'город перемеща лодк', 'сильн ветер порыв', 'шторм', 'шквал', 'бур', 'циклон', 'тайфун', 'пург', 'метел', 'урага', 'порыв достига 20 мс', 'ветрова', 'бурел сдул', 'сорва', 'повал дерев', 'непогод', 'аномальн высок температур', 'волн жар', 'остр тепл', 'экстремальн тепл', 'стрелк термометр подня выш', 'максимум температур последн', 'плав асфальт', 'увелич чил вызов скор помощ', 'кондиционер', 'духот', 'спаст тен', 'nan уровен вод сниз критическ', 'погиб урожа', 'пострада посев', 'обмелел рекиканал', 'дожд', 'низк межен', 'ниж уровн водозабор', 'холод вернул', 'ноч утр температур опуска ниж нул ин', 'лед', 'пострада посев', 'вымерзл', 'врем цветен', 'ледян круп', 'величин орех', 'величин курин яйц', 'ливн', 'жар', 'пострада посев', 'пробоин кровл фасад', 'поб окн', 'автомоб', 'ливен', 'сильн дождьснег', 'снежн ливен', 'снегопад', 'метел', 'вьюг', 'выпа месячн норм', 'поб рекорд', 'дожд смыл', 'снег завал справля ливневк', 'затоп мост', 'сугроб высот крыш', 'коммунальн техник справля', 'машин снежн плен', 'лесн пожар распростран', 'низов пожар', 'верхов пожар', 'жар', 'сгорел', 'пройден огн площад', 'класс пожарн опасн подня', 'сход снег', 'мокр лавин', 'сух лавин', 'период активн снеготаян', 'снежн склон', 'снежн доск', 'ледян доск снег завал', 'разруш здан', 'погребл турист', 'результат интенсивн снеготаян', 'подреза склон', 'грязев поток', 'грязекамен поток', 'селев паводк', 'рек несл камн бревн', 'очен мутн вод', 'заплеск', 'обломк скал', 'размер глыб', 'cмыл', 'снесл', 'погребл сло гряз', 'завал мусор', 'обруш скал', 'сполз склон', 'земл съеха продолжительн дожд', 'завал дорог', 'перекр движен', 'песчан бур', 'ветер подня пыл', 'черн неб', 'мгла', 'летел песок', 'видим сократ', 'концентрац частиц превыша', 'л ...

# %%
def normalize_description(text):
    text  = str(text)
    # Приведение к нижнему регистру
    text = text.lower()

    # Удаление знаков препинания
    text = re.sub(r'[^\w\s]', '', text)

    # Разбиение на слова
    words = word_tokenize(text)

    # Удаление стоп-слов
    stop_words = set(stopwords.words('russian'))
    words = [word for word in words if word not in stop_words]

    stemmer = SnowballStemmer("russian")
    words = [stemmer.stem(word) for word in words]

    return words

def check_situation(text):
    words_found = []
    count = 0
    for word in natural_disaster_words:
        if word in text:
            words_found.append(word)
            count += 1
    return words_found, count

df['text'] = df['ТЕКСТ']
df['update_text'] = df['text'].apply(normalize_text)
df['words_found'], df['count'] = zip(*df['update_text'].apply(check_situation))

# %%
df = df[df['count'] > 1]
df_description = pd.DataFrame()
df_description = df['text']
df_description
# Out:
# 261       🌧️ В ночь на 20 июня в Москве ухудшится погода...
# 714       🥶 В ночь с 11 на 12 мая в столице ожидаются за...
# 1096      ❗️В ночь на 5 апреля в Москве ожидаются заморо...
# 1183      ❗️В Москве сегодня ночью ожидается гололедица....
# 1276      🏥 В Москве открылись первые детские эндоскопич...
#                                 ...
# 125149    «Есть надежда на то, что к началу октября иниц...
# 125180    Ранее МЧС распространило штормовое предупрежде...
# 125208    В Московском регионе из-за шквалистого ветра д...
# 125280    С приходом антициклона теплый день с июльскими...
# 125485    В понедельник, 17 сентября, усилится влияние а...
# Name: text, Length: 1643, dtype: object

# %% [markdown]
# ## Data classify with model

# %%
import requests
import logging
import time
import pandas as pd

time_start = time.time()

logging.basicConfig(filename='api_calls.log', level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')

# Список ваших API ключей]
api_keys = [API_KEY_1, API_KEY_2, API_KEY_3, API_KEY_4, API_KEY_5]
current_key_index = 0


API_ENDPOINT_BASE = "https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent"

headers = {"Content-Type": "application/json"}

def send_question_and_get_answer(question):
    global current_key_index
    API_KEY = api_keys[current_key_index]
    API_ENDPOINT = f"{API_ENDPOINT_BASE}?key={API_KEY}"
    data = {
        "contents": [
            {
                "parts": [
                    {
                        "text": question
                    }
                ]
            }
        ]
    }

    try:
        response = requests.post(API_ENDPOINT, json=data, headers=headers)
        response.raise_for_status()
        return response.json()

    except requests.exceptions.RequestException as e:
        logging.error(f"Ошибка при отправке запроса к API: {e}")
        # Добавьте обработку исключений, например, повторную попытку или пропуск запроса
        return None

# Предположим, что df - ваш DataFrame

texts = []
classes = []

for i in range(0, 1642):
    question = (
        f"Определите, относится ли данная запись из социальной сети к новости о природном "
        f"катаклизме, включая обсуждения последствий или подведения итогов и ликвидации последствий, а также о предупреждениях. "
        f"учитывай, что снегопад и морозы говорят, об одном из природных явлений"
        f"Если да, то укажите ВСЕ классы катаклизмов из списка, которые упомянуты в тексте. "
        f"Учитывайте, что заморозки и пожарная опасность являются взаимоисключающими. \n\n"
        f"Если нет, напишите 'нет'. \n\n"
        f"Текст: {df['text'].iloc[i]} \n\n"
        f"Классы катаклизмов: \n\n {classes_list}.  \n\n"
    )

    api_response = send_question_and_get_answer(question)

    if api_response and 'candidates' in api_response and len(api_response['candidates']) > 0:
        if 'content' in api_response['candidates'][0]:
            final_answer_text = api_response['candidates'][0]['content']['parts'][0]['text']
            print("Итоговый ответ:", final_answer_text)
            print("Исходный текст:", df['text'].iloc[i])

            texts.append(df['text'].iloc[i])
            classes.append(final_answer_text)

        else:
            print(f"Ошибка: ключ 'content' отсутствует в ответе API для i={i}")
            texts.append(df['text'].iloc[i])
            classes.append("Ошибка API")
    else:
        print(f"Ошибка: не получен корректный ответ API для i={i}")
        texts.append(df['text'].iloc[i])
        classes.append("Ошибка API")

    # Переключение на следующий API ключ
    current_key_index = (current_key_index + 1) % len(api_keys)

    # Добавьте паузу, чтобы избежать превышения лимитов API
    time.sleep(1)
    print('i=', i)

time_end = time.time()
print("Прошло времени", time_end - time_start)

# Создание DataFrame после завершения цикла
results_df = pd.DataFrame({'text': texts, 'class': classes})
results_df.to_csv('/content/drive/MyDrive/HSE_project/ЦФО/preprocessing_data/26072024_Moscow_test_results_0_1642.csv')
# Out:
# Итоговый ответ: нет
# Исходный текст: 🌧️ В ночь на 20 июня в Москве ухудшится погода.   Ожидается дождь, гроза и шквалистый ветер. В отдельных районах пройдет ливень с градом. Такая погода сохранится до позднего вечера.  Будьте внимательны на улице!
# i= 0
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Заморозки
# Исходный текст: 🥶 В ночь с 11 на 12 мая в столице ожидаются заморозки. По прогнозам синоптиков, температура опустится до минус одного градуса, возможна гололедица.    Рекомендуем пешеходам быть осторожными на улице. Водителям необходимо строго соблюдать дистанцию и отказаться от резких маневров.  Больше о погоде в столице: https://www.mos.ru/news/item/138467073.
# i= 1
# Итоговый ответ: Да, это новость о природном катаклизме.
#
# Класс катаклизма: Заморозки
# Исходный текст: ❗️В ночь на 5 апреля в Москве ожидаются заморозки.  По прогнозам синоптиков, столбики термометров опустятся ниже нуля градусов. Будьте аккуратны, на дорогах возможна гололедица.
# i= 2
# Итоговый ответ: Да
#
# Класс катаклизмов: Гололедно-изморозевые явления
# Исходный текст: ❗️В Москве сегодня ночью ожидается гололедица.    По прогнозам синоптиков, температура воздуха опустится ниже нуля градусов.    Пешеходам следует быть внимательными и аккуратными на улице, а автомобилистам — строго соблюдать скоростной режим и дистанцию.
# i= 3
# Итоговый ответ: нет
# Исходный текст: 🏥 В Москве открылись первые детские эндоскопические центры.    Теперь исследования для юных пациентов с гастроэнтерологическими заболеваниями проводят в условиях дневного стационара. Процедура занимает буквально несколько часов, после этого можно отправиться домой.    Пилотный проект запущен на базе Морозовской детской больницы и детской больницы имени Башляевой. Центры оснащены современным оборудованием, которое позволяет проводить максимально комфортные исследования для маленьких пациентов: mos.ru/news/item/136371073
# i= 4
# Итоговый ответ: Да, это новость о природном катаклизме, относящемся к классу:
#
# * Гололедно-изморозевые явления
# Исходный текст: 🌧 С 18:00 в Москве ожидается ледяной дождь. На дорогах возможна гололедица. Такая погода продлится до 09:00 понедельника.    Рекомендуем пешеходам быть внимательными на улице, автомобилистам — соблюдать скоростной режим и дистанцию и не парковать транспорт рядом с деревьями и линиями электропередачи.
# i= 5
# Итоговый ответ: Да, это новость о природном катаклизме, включающая обсуждение последствий (снегопад и коммунальные службы по уборке снега).
#
# Класс катаклизма: Сильные атмосферные осадки
# Исходный текст: 🌨 В субботу в Москве ожидается снегопад, который продлится до вечера воскресенья.    Специалисты следят за ситуацией на дорогах. Кроме того, коммунальные службы продолжают убирать улицы от снега. Просим водителей соблюдать дистанцию и скоростной режим.
# i= 6
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
#  ['Сильные атмосферные осадки: Очень сильные дождь/снег. Обычно, с нетипично сильными для региона осадками плохо справляются коммунальщики, инженерные сооружения (e.g. забитые ливневки), под снегом падают деревья и ЛЭП.']
# Исходный текст: 🌨 Городские службы в круглосуточном режиме ликвидируют последствия снегопада.    Помимо штатных сотрудников, к работе дополнительно привлекли силы инженерных компаний. Пешеходам рекомендуем пользоваться общественным транспортом, а водителям быть аккуратнее и соблюдать скоростной режим.
# i= 7
# Итоговый ответ: Да, новость относится к природному катаклизму.
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки
# Исходный текст: Городские службы готовы к предстоящему снегопаду 🌨️  Прирост снега составит больше 11 сантиметров. Для устранения последствий непогоды задействуют более 14 тысяч единиц техники. Она будет непрерывно очищать проезжую часть, тротуары и дворы и проводить противогололедную обработку.  Просим с пониманием относиться к работе коммунальных служб и не препятствовать движению колонн техники.
# i= 8
# Итоговый ответ: Да
#
# 'Сильные атмосферные осадки'
# Исходный текст: В столице продолжают ликвидировать последствия сильного снегопада.  В отдельных районах Москвы выпало свыше 60 процентов месячной нормы осадков. Прирост снега составил до 18–23 сантиметров. В его уборке задействованы 150 тысяч человек и 14 тысяч единиц техники.
# i= 9
# Итоговый ответ: Да, это новость о природном катаклизме, включающая обсуждения последствий и предупреждения.
#
# Упомянутые в тексте классы катаклизмов:
#
# * Снегопад
# * Наледеобразование
# * Гололедно-изморозевые явления
# * Заморозки
# Исходный текст: Городские службы продолжают убирать улицы после снегопада ❄    Специалисты чистят парковки, тротуары, дворы, убирают наледь с кровель домов. Пешеходов просят быть внимательными и не заходить за ограждения, а автомобилистов — строго соблюдать скоростной режим и дистанцию.    Также предупреждаем: сегодня температура поднимется до плюс одного градуса. В связи с этим возможна гололедица.
# i= 10
# Итоговый ответ: Да
#
# Классы катаклизмов:
# 'Сильные атмосферные осадки'
# 'Ураганы, смерчи, сильный ветер'
# 'Заморозки'
# Исходный текст: 🌨 Завтра днем и в ночь на 19 января в Москве ожидается снегопад и метель. Кроме того, синоптики прогнозируют порывы ветра до 15 метров в секунду.    Просим вас быть внимательными и осторожными! Сообщить о последствиях непогоды можно по телефону или с помощью городских сервисов.
# i= 11
# Итоговый ответ: нет
# Исходный текст: ⛸ В этом сезоне в Москве открыто около 160 катков на свежем воздухе с искусственным льдом.    Они работают в снегопад, мороз и даже теплую погоду (которая обязательно наступит). Специальная технология не позволяет льду таять при плюсовой температуре, а своевременная полировка делает его ровным и гладким.    Как создается такой каток, для чего предназначен ледовый комбайн, как ухаживают за искусственным льдом и поддерживают его температуру — читайте в нашем материале: mos.ru/news/item/133826073/
# i= 12
# Итоговый ответ: нет
# Исходный текст: 🛞 Дорожный патруль ЦОДД с начала года помог столичным водителям более 41 тысячи раз.  Город круглосуточно патрулируют 30 экипажей. Они следят за порядком на дорогах в режиме 24/7 и помогают автомобилистам, попавшим в сложные ситуации.  Рассказываем, как патруль делает движение безопаснее: url.mos.ru/zz5-jqn
# i= 13
# Итоговый ответ: нет
# Исходный текст: 🎄 Офисы «Мои документы» тоже будут встречать Новый год. Посетители смогут там получить подарки от Деда Мороза, поучаствовать в мастер-классах и послушать детские новогодние чтения.    С 25 декабря во всех центрах госуслуг появятся елки будущих достижений, на которых можно разместить открытку с обещаниями самому себе и целями на следующий год.    Подробнее: url.mos.ru/92g-kxv
# i= 14
# Итоговый ответ: Да, относится.
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки
# * Заморозки
# Исходный текст: ❄️ Сейчас уборка снега — задача номер один для коммунальных служб.   В столице в эти дни рекордные снегопады. Для устранения их последствий в городе дополнительно привлекут 10–12 тысяч работников.  Погодные условия тяжелые. По прогнозам синоптиков, снег будет идти всю неделю.
# i= 15
# Итоговый ответ: Да, относится
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки (снег)
# Исходный текст: 🌨️ Весь день городские службы устраняют последствия снегопада.  Специалисты очищают от снега и наледи улицы, дворы и крыши домов. Для безопасности пешеходов места проведения работ огораживают лентами и специальными заграждениями.   📽️ [https://vk.com/infokgh|Комплекс городского хозяйства]
# i= 16
# Итоговый ответ: Да.
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки (снег)
# Исходный текст: ⚠️ Завтра в Москве ожидается сильный снегопад.  По прогнозам синоптиков, он будет идти почти весь день. Городские службы готовы работать в усиленном режиме.  Автомобилистам рекомендуется строго следовать правилам дорожного движения, а пешеходам — выбирать удобную обувь,не стоять под деревьями и шаткими конструкциями.
# i= 17
# Итоговый ответ: нет
# Исходный текст: 🍲 В рамках выставки «Россия» на ВДНХ проходит самый вкусный фестиваль — гастрономический!   На нем представлены кулинарные традиции разных регионов нашей страны: от Калининграда до Камчатки. В меню бурятская, дальневосточная, донская, поморская, сибирская и другие кухни, а также старинная русская уличная еда.   Гостей ждут не только дегустации и мастер-классы, но и музыкальные выступления. Подробнее: url.mos.ru/k8r-xgw
# i= 18
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Заморозки
# Исходный текст: В ночь на 25 октября ожидается минусовая температура 🥶    Городские службы следят за ситуацией на дорогах. При необходимости будет проведена противогололедная обработка улиц.    Автомобилистов просим обратить внимание на нашу памятку 👇
# i= 19
# Итоговый ответ: нет
# Исходный текст: Пост для автомобилистов 🚗    Несмотря на похолодание, пока не рекомендуется менять летнюю резину на зимнюю. В следующие выходные в Москве прогнозируется потепление до 10–12 градусов.
# i= 20
# Итоговый ответ: Да.
#
# Классы катаклизмов:
#
# * Заморозки
# Исходный текст: ❗Вечером 6 октября в Москву придут первые заморозки. В ночь на субботу температура понизится до минус двух градусов. На дорогах местами возможна гололедица.    Просим водителей быть внимательными и осторожными, не совершать резких маневров и соблюдать скоростной режим.    Городские службы работают в усиленном режиме. На круглосуточном дежурстве находится 1,5 тысячи аварийных бригад: url.mos.ru/5nk-kgy
# i= 21
# Итоговый ответ: нет
# Исходный текст: В День театра мы решили отыскать следы сценического искусства в парках и усадьбах города.    Одни хранят воспоминания о постановках, которым рукоплескали Екатерина II и ее современники, в других и по сей день раздаются аплодисменты.    Рассказываем о пяти парках, в которых можно найти театры или следы сценического искусства: https://url.mos.ru/22q-xjx    #парки@mos #MosRu
# i= 22
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки
# * Ветер >10 м/с
# * Гололедно-изморозевые явления
# Исходный текст: ⚠ Внимание! В ночное время в городе резко ухудшится погода. Ожидается ветер с порывами до 15–20 метров в секунду и сильный снег.    Также возможно образование гололедицы и снежных заносов. Просим автомобилистов соблюдать скоростной режим и быть внимательнее на дорогах.    Пешеходам советуем обходить линии электропередачи, деревья и шаткие конструкции.  #погода@mos #MosRu
# i= 23
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки
# Исходный текст: Сильный снегопад сохранится в столице до утра. Возможны снежные заносы, гололедица ❄    Автолюбителей и пешеходов просят быть аккуратнее: https://url.mos.ru/kp7-my5    #погода #MosRu
# i= 24
# Итоговый ответ: Да.
#
# Классы катаклизмов:
# - Сильные атмосферные осадки
# Исходный текст: 🚜 Коммунальные службы продолжают работать в усиленном режиме чтобы устранить последствия снегопада.    За прошедшие сутки в городе выпало 25 сантиметров снега – 60 процентов месячной нормы осадков: url.mos.ru/6mp-m3q  #MosRu
# i= 25
# Итоговый ответ: нет
# Исходный текст: 🎅 В столицу приедут Деды Морозы из 14 регионов России. Пообщаться с ними можно будет с 5 января в парках, вагонах новогоднего поезда метро, на колесе обозрения на ВДНХ и нескольких других площадках.    Зимние волшебники расскажут о том, как празднуется Новый год в Кабардино-Балкарии, Татарстане, Бурятии, Карелии и в десятке других регионов: https://url.mos.ru/pqx-z4n    #MosRu
# i= 26
# Итоговый ответ: Да, относится.
#
# Классы катаклизмов:
#
# * Снегопад
# * Гололед
# Исходный текст: ⚠ Сегодня с 21:00 в Москве ожидается снегопад. Также сохранится гололедица.    Пожалуйста, будьте внимательны и осторожны!    О том, куда сообщить о неубранном снеге, показываем на карточке ⬇    #MosRu
# i= 27
# Итоговый ответ: нет
# Исходный текст: Хорошие новости о предстоящих выходных: снегопадов и сильных морозов не ожидается  #погода #MosRu
# i= 28
# Итоговый ответ: нет
# Исходный текст: С приходом морозов на столичных водоемах появился первый лед. Но выходить на него пока не стоит. Несколько советов по безопасности ⤵
# i= 29
# ERROR:root:Ошибка при отправке запроса к API: 500 Server Error: Internal Server Error for url: https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?key=AIzaSyCfULiIs2-rnPDf_1l4Xg3MNIx17tDtIOc
# Ошибка: не получен корректный ответ API для i=30
# i= 30
# Итоговый ответ: Да
#
# Классы катаклизмов:
# - Заморозки
# - Гололедно-изморозевые явления
# Исходный текст: ❗Ночью в Москве ожидаются заморозки до минус четырех градусов. Это способствует образованию гололедицы.    Будьте внимательны на дорогах и срочно поменяйте летнюю резину на зимнюю, если еще не сделали этого.  #погода@mos #MosRu
# i= 31
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки
# * Снегопад
# * Заморозки
# Исходный текст: Техника, которую должен освоить каждый город зимой, – снегоуборочная 👌🏻    Подглядели за работой специалистов по ликвидации последствий снегопада  📷 Евгений Самарин  #MosRu
# i= 32
# Итоговый ответ: нет
# Исходный текст: Еноты Шторми и Джони, хорек Рикки и львица Бубу 😎    Каких необычных питомцев москвичи приводят на прием к ветеринарам:    https://url.mos.ru/qy2-qv6    #MosRu
# i= 33
# Итоговый ответ: да
#
# **Классы катаклизмов:**
#
# * Заморозки
# * Сильные атмосферные осадки (снег)
# Исходный текст: Немного снега и крепкий мороз: рецепт погоды на последнюю неделю 2021 года ❄  #погода@mos #MosRu
# i= 34
# Итоговый ответ: Да, относится.
#
# Классы катаклизмов:
#
# * Заморозки
# Исходный текст: Экстренное предупреждение ⚠    В ночь с 28 на 29 сентября местами в Москве ожидаются заморозки и минусовая температура 🥶    Рекомендуем пешеходам утепляться, а автомобилистам быть аккуратнее на дорогах    #погода #MosRu
# i= 35
# Итоговый ответ: нет
# Исходный текст: Чем удивляет Москва в Дни исторического и культурного наследия?    Не только уже полюбившимися Домом Наркомфина, Северным речным вокзалом и кинотеатром «Художественный», но и другими шедеврами архитектуры. Например, городской усадьбой Каратаевой – Морозова в Леонтьевском переулке и доходным домом купца Быкова на 2-й Брестской улице 🏛    Узнайте больше здесь: bit.ly/3wkGB06  📷 Юлия Иванко    #архитектура@mos #MosRu
# i= 36
# Итоговый ответ: нет
# Исходный текст: 😎 Сегодня последний морозный день на этой неделе!  😞 Но, увы, и последний солнечный…    #погода #MosRu
# i= 37
# Итоговый ответ: нет
# Исходный текст: За окном снег и мороз, а в ваших устройствах теплый мир итальянской музыки в исполнении артистов Театра Бориса Певзнера 🇮🇹  В программе классические композиции, неаполитанские песни и пародия на оперу.  Последнее особенно интригует. Включайте прямо сейчас!  #трансляции #культура@mos #MosRu
# i= 38
# Итоговый ответ: нет
# Исходный текст: Зимний учет животных в столице проводится по их следам. Это позволяет специалистам [club70051731|Мосприроды] определить видовой состав и численность зверей на большом пространстве.    Главное условие этого метода – снежный покров, на котором хорошо видны следы животных. Замеры обычно делают на следующий день после ночного снегопада. Если его не было, то старые отпечатки лап затирают и фиксируют новые.    Для наименьшей погрешности в расчетах маршруты, по которым ведется учет, не меняются. Каждый год экологи фиксируют следы, замеченные на маршруте, а затем указывают точки пересечения и вид животного на карте или в GPS-навигаторе.    Как правильно «читать» следы животных, сколько длится зимний учет зверей и кого исследователи обнаружили в начале 2020 года рассказываем в нашем материале:    bit.ly/2KfZfEo  #природа@mos #MosRu
# i= 39
# Итоговый ответ: нет
# Исходный текст: Кто любит прогулки по городу? Кто любит узнавать новое? Кто не боится морозов? Последнее – шутка, а вот больше 110 бесплатных экскурсий – реальность!  Регистрируйтесь и гуляйте по Москве Булгакова, в парке Горького, на ВДНХ и не только:  http://bit.ly/37DSz8E  #культура #экскурсии #ДеньГида #MosRu
# i= 40
# Итоговый ответ: нет
# Исходный текст: Уже придумали, что попросите у Деда Мороза? Тогда следуйте нашей инструкции:  📩 пишем письмо,   🏃‍♂идем в парк,  📮 опускаем в ящик,  🎁 ждем подарка.    #зима #праздник #НовыйГод #MosRu
# i= 41
# Итоговый ответ: да
# ['Сильные атмосферные осадки']
# Исходный текст: Будьте осторожны! В столице ожидаются проливные дожди и шквалистый ветер. В связи с этим столичные парки закроются:   https://www.mos.ru/news/item/60058073/    #погода@mos #MosRu
# i= 42
# Итоговый ответ: Да, относится.
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки
# * Гололедно-изморозевые явления
# Исходный текст: Плохая погода продержится в Москве до конца дня: обещают сильный снегопад, порывы ветра до 17 метров в секунду и образование гололедицы  https://www.mos.ru/news/item/51842073/  #Москва #погода #снегопад
# i= 43
# Итоговый ответ: Да
#
# Класс катаклизма: "Сильные атмосферные осадки"
# Исходный текст: Снег, ты не пройдешь! О борьбе с последствиями сильного снегопада:  [club151870667|Комплекс городского хозяйства]  #снег #ЖКХ
# i= 44
# Итоговый ответ: Да
#
# Катаклизмы:
# - Заморозки
# Исходный текст: Готовим пледы, вкусную еду и пару хороших фильмов для просмотра дома: в выходные ожидается метель и мороз  #Москва #город #погода #прогноз
# i= 45
# Итоговый ответ: Да.
#
# Классы катаклизмов:
# * Заморозки
# * Гололедно-изморозевые явления
# Исходный текст: Скоро ударят морозы, но в выходные будет относительно тепло. 🙂 Местами пройдет небольшой снег. На дорогах сильная гололедица, будьте осторожны!  #Москва #погода
# i= 46
# Итоговый ответ: Да, это новость о природном катаклизме, включающая обсуждения последствий.
#
# **Классы катаклизмов:**
#
# * Ураганы, смерчи, сильный ветер
# * Сильные атмосферные осадки
# Исходный текст: Зоопарк, фан-зона ЧМ-2018 и парки закрыты 30 июня из-за непогоды. В столице ожидается шквалистый ветер с порывами до 20 метров в секунду, сильный дождь, гроза, местами град. Будьте внимательны!  https://www.mos.ru/news/item/42180073/  #погода #москва #ветер #дождь #гроза
# i= 47
# Итоговый ответ: Да.
#
# Классы катаклизмов:
#
# * 'Ураганы, смерчи, сильный ветер'
# Исходный текст: Главное управление МЧС призывает быть внимательными и осторожными: в столице объявлено штормовое предупреждение!  https://www.mos.ru/news/item/39398073/    #погода #предупреждение #ветер #шторм
# i= 48
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Сильные атмосферные осад
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Ураганы, смерчи, сильный ветер
# Исходный текст: 💪В Северном Медведково устраняют последствия шквалистого ветра.
# i= 61
# Итоговый ответ: Да, данная запись относится к новости о природном катаклизме.
#
# Упомянутые классы катаклизмов:
#
# * Ураганы, смерчи, сильный ветер
# Исходный текст: 💪В Северном районе шквалистый ветер повалил несколько деревьев. Жилищник уже на месте!    Долгопрудная аллея и 1-я Северная линия
# i= 62
# Итоговый ответ: нет
# Исходный текст: В СВАО работает пункт приема крови в ГКБ им. А.К. Ерамишанцева ДЗМ, ул.Ленская, д.15.   А так же в следующих пунктах по городу:   — Центр крови ФМБА, Щукинская улица, 6к2, — Донорский центр на Беговой, ул. Поликарпова, д. 14, стр. 1,  — Донорский центр Царицыно, ул. Бакинская, д. 31, — Донорский центр на Шаболовской, ул. Шаболовка, 57, — Центр крови имени О.К.Гаврилова, ул. Поликарпова, д.14, корп.2, — ул. Бакинская, д.31  — ГКБ №1, Ленинский проспект, д. 10, к. 1, — ГКБ им. М.П. Кончаловского ДЗМ, Зеленоград, Каштановая аллея, д. 2, стр. 1, — ГКБ №52 ДЗМ, ул.Пехотная, д. 3, — ГКБ №67, ул. Саляма Адиля, д. 2, — ГКБ им. Е.О. Мухина ДЗМ, Федеративный проспект, д. 17 — ГКБ им. В.М. Буянова ДЗМ, ул. Бакинская, д.26, — Морозовская ДГКБ ДЗМ, 4-й Добрынинский переулок, д. 1/9, корпус 9, — ГКБ им. C.С. Юдина ДЗМ, Севастопольский проспект, д. 24А.  Специалисты всех городских служб работают круглосуточно. Пострадавшим оказывается медицинская и психологическая помощь.
# i= 63
# Итоговый ответ: Да.
#
# Классы катаклизмов:
#
# * Снегопад
# * Сильные атмосферные осадки
# Исходный текст: ❄Коммунальные службы округа ликвидируют последствия ночного снегопада.    💪На связи Бутырский район. За ночь прирост свежевыпавшего снега составил до 3 см. По прогнозу синоптиков в течение дня снег будет продолжать идти. Коммунальные службы непрерывно мониторят состояние улично-дорожной сети и проводят регламентные работы в соответствии с погодными условиями.   Первым делом очищаем пешеходные зоны, тротуары, подходы к остановкам общественного транспорта, станциям метро и МЦК, железнодорожным станциям и платформам, ТПУ, объектам социальной сферы и потребительского рынка.    #СВАО_в_эфире
# i= 64
# Итоговый ответ: нет
# Исходный текст: С 8 по 14 января проходит Неделя продвижения активного образа жизни  🏂🏻 Активный образ жизни зимой.   ❄ Зима - прекрасное время года, дарящее красоту заснеженных деревьев, тепло домашнего очага и весёлые забавы на свежем воздухе.   ✳ Если вы привыкли выполнять упражнения на свежем воздухе, то вот несколько рекомендаций.   Даже если вы очень не любите разминку, перед зимней тренировкой она обязательна: так вы убережете суставы от переохлаждения и накопите ресурс тепла для начала тренировки.   ✳ Заниматься зимой лучше рядом с местом, где после тренировки можно погреться. На морозе нельзя прекращать физическую активность. Например, если вы занимаетесь на турниках, между подходами ни в коем случае не стойте долго на одном месте и не садитесь передохнуть на скамейку. Ходите, делайте махи ногами и руками. Во время пробежки на последних 100 метрах до дома перейдите на быстрый шаг, сделайте плавную динамическую разминку, не останавливайтесь.   ✳ Во время тренировок на улице зимой организм теряет больше воды
# i= 68
# Итоговый ответ: нет
# Исходный текст: 🐾Все еще ходите без шапки? Тогда мы идем к вам!   Врачи предупредили о последствиях привычки ходить без шапки зимой:   🤕Отсутствие шапки в мороз может привести к переохлаждению головного мозга и спровоцировать множество заболеваний, например, насморк и воспаление среднего уха.   😷Кроме того, есть вероятность заразиться стрептококком группы А, который является возбудителем скарлатины, ангины, а также неизлечимой болезни почек — гломерулонефрита.   🤒Шансы заболеть менингитом очень малы, ведь это заболевание имеет инфекционную природу. Но если человек уже простужен или имеет хронический тонзиллит, гайморит, фарингит или синусит, то из-за переохлаждения может произойти вторичное воспаление, которое и разовьётся в менингит.   Носите шапку зимой! Берегите себя!
# i= 69
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки (Снегопад)
# * Заморозки
# Исходный текст: В СВАО повсеместно ведутся работы по уборке улиц и дворов. Вывозим снег, проводим противогололедную обработку.    Погодные условия достаточно тяжелые. Коммунальные службы работают в непрерывном режиме.    ❗На улицах города работает снегоуборочная и погрузочная техника. Благодарим автомобилистов за понимание.
# i= 70
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# - Сильные атмосферные осадки
# Исходный текст: Коммунальные службы округа в усиленном режиме ликвидируют последствия снегопада❄❄❄   В уборке задействовано максимальное количество людей и техники.    Уважаемые жители СВАО! Просим вас быть предельно внимательными и аккуратными на тротуарах и дорогах в непогоду, по возможности – перенести поездки на личном транспорте.
# i= 71
# Итоговый ответ: да
#
# **Классы катаклизмов:**
#
# * Снегопад
# * Гололедно-изморозевые явления
# * Заморозки
# Исходный текст: ❗️Окружные службы переведены в режим повышенной готовности из-за снегопада  Согласно прогнозу прирост снега может составить до 10 сантиметров.   С 23:00 будет проводиться прометание проезжей части и тротуаров, а также противогололедная обработка. Цикл работ при необходимости будет повторен.  Особое внимание будет уделяться очистке пешеходных зон, тротуаров, подходов к остановкам общественного транспорта, объектам социальной сферы и потребительского рынка.   ❗️Уважаемые жители СВАО! Просим быть предельно внимательными и аккуратными на тротуарах и дорогах.
# i= 72
# Итоговый ответ: нет
# Исходный текст: 🐾🏠 Проведите выходные с пользой!   Приглашаем вас на новую интереснейшую лекцию в рамках "Школы Приёмных Родителей" от волонтёров приюта Искра!   ️В эту субботу мы расскажем вам об особенностях поведения собак в приюте и как адаптировать собаку из приюта дома. После лекции вы обязательно прогуляетесь по парку в компании наших забавных пушистых подопечных! Обещаем шквал положительных эмоций!   Приходите всей семьёй провести эту субботу вместе с нашей дружной искринской семьёй и оставьте свой след в судьбе наших пушистых друзей!   🐾❤ Ссылка на регистрацию: https://ekotsentr-yauza-event.timepad.ru/event/2672495/  По всем вопросам Анастасия +7 916 199 8161  📅 18 ноября, 12:00-14:00  🏢 Экоцентр Яуза (Юрловский пр., 10/4)
# i= 73
# Итоговый ответ: нет
# i= 77
# Итоговый ответ: нет
# Исходный текст: Завтра стартует 45-й Московский Международный Кинофестиваль   Он пройдет с 20 по 27 апреля 2023 года. Московский международный кинофестиваль — один из старейших кинофорумов в мире и один из самых авторитетных наряду с фестивалями в Берлине, Каннах, Сан-Себастьяне, Венеции, и Карловых Варах.   Впервые он проводился в 1935 году, председателем жюри был Сергей Эйзенштейн.   Свои работы представят кинематографисты из разных уголков планеты – от Аргентины и Перу до Индии, Китая и стран Ближнего Востока, а уровень картин ожидается высоким, как никогда прежде.   Традиционно оценивать картины будут в нескольких категориях: основной конкурс, документальное и короткометражное кино, конкурс «Русские премьеры», а также внеконкурсные показы.   Фильмом открытия станет «Снегирь» режиссера Бориса Хлебникова. Это история экипажа одноименного рыболовного судна, которое попадает в шторм. Премьера в рамках фестиваля состоится 20 апреля.   Как попасть на показы?  Ежегодно на церемонию открытия и закрытия фестиваля приглашаются известные режиссеры и актеры, а в показах участвуют десятки различных картин, привлекающих внимание поклонников кинематографа. Попасть на официальные мероприятия со звездами можно лишь по пригласительным или билетам, достать которые очень сложно, а вот просто насладиться фильмами гораздо легче. Билеты можно приобрести сразу на месте или на сайте фестиваля.  https://45.moscowfilmfestival.ru/
# i= 78
# ...
# - Гололедица
# Исходный текст: «В ближайшие 1—3 часа с сохранением ночью и в первой половине дня 16 декабря в Москве ожидается туман с видимостью 200—700 метров, изморозь, на дорогах гололедица», — говорится в сообщении ведомства в Twitter. Ранее синоптики предупредили о резком понижении температуры в Москве в выходные.
# i= 1584
# Итоговый ответ: Да, это новость о природном катаклизме.
#
# Классы катаклизмов, упомянутые в тексте:
#
# * Гололедно-изморозевые явления
# * Туман, мгла, условия медленного рассеивания загрязняющих веществ
# Исходный текст: По прогнозам синоптиков Росгидромета в ближайшие 1-3 часа с сохранением ночью и в первой половине дня 16 декабря в городе Москве ожидается туман с видимостью 200-700 метров, изморозь, на дорогах гололедица, - уточняет МЧС.
# i= 1585
# Итоговый ответ: да
#
# Классы катаклизмов:
#
# * Гололедно-изморозевые явления
# * Туман, мгла, условия медленного рассеивания загрязняющих веществ
# Исходный текст: В Москве 16 декабря ожидается туман, изморозь и гололедица, предупредило управление МЧС по столице.
# i= 1586
# Итоговый ответ: Да, это новость о природном катаклизме (гололедно-изморозевые явления).
#
# Классы катаклизмов, упомянутые в тексте:
#
# * Гололедно-изморозевые явления
# Исходный текст: В Москве 16 декабря ожидается туман, изморозь и гололедица, предупредило управление МЧС по столице.
# i= 1587
# Итоговый ответ: Да, новость относится к природному катаклизму.
#
# Классы катаклизмов, упомянутые в тексте:
#
# * Гололедно-изморозевые явления
# * Туман, мгла, условия медленного рассеивания загрязняющих веществ
# Исходный текст: «В ближайшие 1—3 часа с сохранением ночью и в первой половине дня 16 декабря в Москве ожидается туман с видимостью 200—700 метров, изморозь, на дорогах гололедица», — говорится в сообщении ведомства в Twitter. Ранее синоптики предупредили о резком понижении температуры в Москве в выходные.
# i= 1588
# Итоговый ответ: нет
# Исходный текст: По прогнозам синоптиков Росгидромета в ближайшие 1-3 часа с сохранением ночью и в первой половине дня 16 декабря в городе Москве ожидается туман с видимостью 200-700 метров, изморозь, на дорогах гололедица, - уточняет МЧС.
# i= 1589
# Итоговый ответ: Да.
#
# Классы катаклизмов:
#
# * Туман, мгла, условия медленного рассеивания загрязняющих веществ
# * Гололедно-изморозевые явления
# Исходный текст: По прогнозам синоптиков Росгидромета в ближайшие 1-3 часа с сохранением ночью и в первой половине дня 16 декабря в городе Москве ожидается туман с видимостью 200-700 метров, изморозь, на дорогах гололедица, - уточняет МЧС.
# i= 1590
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Гололедно-изморозевые явления
# Исходный текст: «В ближайшие 1—3 часа с сохранением ночью и в первой половине дня 16 декабря в Москве ожидается туман с видимостью 200—700 метров, изморозь, на дорогах гололедица», — говорится в сообщении ведомства в Twitter. Ранее синоптики предупредили о резком понижении температуры в Москве в выходные.
# i= 1591
# Итоговый ответ: Да, это новость о природном катаклизме, которая включает в себя предупреждения.
#
# Классы катаклизмов, упомянутые в тексте:
#
# * Гололедно-изморозевые явления
# * Туман, мгла, условия медленного рассеивания загрязняющих веществ
# * Аномально холодная погода
# * Резкие перепады температуры
# Исходный текст: «В ближайшие 1—3 часа с сохранением ночью и в первой половине дня 16 декабря в Москве ожидается туман с видимостью 200—700 метров, изморозь, на дорогах гололедица», — говорится в сообщении ведомства в Twitter. Ранее синоптики предупредили о резком понижении температуры в Москве в выходные.
# i= 1592
# Итоговый ответ: Да.
#
# Классы катаклизмов:
#
# * Гололедно-изморозевые явления
# * Туман, мгла, условия медленного рассеивания загрязняющих веществ
# Исходный текст: «В ближайшие 1—3 часа с сохранением ночью и в первой половине дня 16 декабря в Москве ожидается туман с видимостью 200—700 метров, изморозь, на дорогах гололедица», — говорится в сообщении ведомства в Twitter. Ранее синоптики предупредили о резком понижении температуры в Москве в выходные.
# i= 1593
# Итоговый ответ: Да.
#
# Классы катаклизмов:
#
# ['Гололедно-изморозевые явления']
# Исходный текст: «В ближайшие 1—3 часа с сохранением ночью и в первой половине дня 16 декабря в Москве ожидается туман с видимостью 200—700 метров, изморозь, на дорогах гололедица», — говорится в сообщении ведомства в Twitter. Ранее синоптики предупредили о резком понижении температуры в Москве в выходные.
# i= 1594
# Итоговый ответ: Да, это новость о природном катаклизме.
#
# Классы катаклизмов, упомянутые в тексте:
#
# * Заморозки
# Исходный текст: Сильные морозы нагрянут в Москву на выходных, низкая температура не покинет столицу до середины следующей недели. Синоптики сообщают, что в субботу днем в Москве температура воздуха опустится до 7 градусов мороза. В воскресенье стоит ожидать похолодание до 14-12 градусов.
# i= 1595
# Итоговый ответ: 'Заморозки'
# Исходный текст: Морозы до 17 градусов ожидаются в Москве на следующей неделе. Об этом сообщает Гидрометцентр.
# i= 1596
# Итоговый ответ: нет
# Исходный текст: Сильные морозы придут в Москву в выходные и продержатся до середины следующей недели.
# i= 1597
# Итоговый ответ: нет
# Исходный текст: Синоптики предупредили москвичей о грядущих на следующей неделе морозах. Значительно похолодает в Москве уже к ближайшим выходным, а с понедельника, 17 декабря, в столичном регионе температура воздуха ночью может понизиться до минус 16 градусов. Днем будет немного теплее - минус 12.
# i= 1598
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Заморозки
# Исходный текст: Морозы до 17 градусов ожидаются в Москве на следующей неделе. Об этом сообщает Гидрометцентр.
# i= 1599
# Итоговый ответ: Да, это новость о природном катаклизме.
#
# Классы катаклизмов, упомянутые в тексте:
# - Сильные атмосферные осадки: снег и гололед
# Исходный текст: В московских аэропортах из-за снегопада задержано более 40 рейсов. Согласно информации сервиса «Яндекс.Расписание», во Внуково задерживаются 14 рейсов, в Шереметьево — 18 рейсов, в Домодедово 12 задержано и 8 отменено. По данным Гидрометцентра, 13 декабря в Москве ожидаются снег и гололедица.
# i= 1600
# Итоговый ответ: нет
# Исходный текст: Динамо во вторник со счетом 3:1 обыграло "Северсталь" в последнем для "бело-голубых" домашнем матче регулярного чемпионата КХЛ на арене "Мегаспорт". Следующий домашний матч – 4 января против "Автомобилиста" из Екатеринбурга – "Динамо" проведет уже на своей новой арене в Петровском парке.
# i= 1601
# Итоговый ответ: нет
# Исходный текст: Сегодня, 10 декабря, «Автомобилист» провёл последний матч домашней серии. Екатеринбургская команда встречалась с московским «Спартаком». Игра завершилась со счётом 4:1 в пользу «Автомобилиста».
# i= 1602
# Итоговый ответ: да
#
# классы катаклизмов:
# ['Снег', 'Заморозки', 'Сильные атмосферные осадки']
# Исходный текст: В Москву пришли первые сильные снегопады. По прогнозам синоптиков, они продолжатся до конца следующей недели, передает телеканал «МИР 24». К утру же, как ожидается, сугробы вырастут на семь сантиметров.
# i= 1603
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Сильные атмосферные осадки (снег)
# * Заморозки
# * Гололедно-изморозевые явления
# Исходный текст: В Москве в ночь на 6 декабря ожидается сильный снегопад. Об этом сообщает агентство городских новостей «Москва» со ссылкой на Гидрометцентр. Отмечается, что ночь будет облачной, местами образуется гололедица, а скорость юго-западного ветра составит до 5–10 м/с.
# i= 1604
# Итоговый ответ: нет
# Исходный текст: Мокрый снег и температура воздуха около 0 градусов ожидаются в Москве уже в середине следующей недели, проинформировали синоптики центра погоды "Фобос", При этом специалисты уточняют, что в начале новой рабочей недели температура воздуха составит от -2 до -5 градусов мороза.
# i= 1605
# Итоговый ответ: да
#
# Классы катаклизмов:
#
# * Наледеобразование
# * Сильный ветер
# * Заморозки
# * Гололедно-изморозевые явления
# Исходный текст: Порывистый ветер и гололедица на дорогах В Москве объявлен желтый уровень опасности из-за снегопада, сообщили в пресс-службе ГУ МЧС России по столице.
# i= 1606
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# ['Заморозки']
# Исходный текст: Синоптики объявили «желтый» уровень погодной опасности в Москве и области из-за снега и гололедицы. В ночь на 3 декабря температура воздуха в Москве опустится до 10 градусов мороза.
# i= 1607
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# - Заморозки
# - Гололедно-изморозевые явления
# - Сильные атмосферные осадки
# Исходный текст: В ночь на воскресенье ожидаются снегопад и гололедица В московском регионе объявлен "желтый" уровень погодной опасности.
# i= 1608
# Итоговый ответ: нет
# Исходный текст: Днем число "заминированных" ТЦ выросло до 14, а количество эвакуированных - до 6 тыс. человек. Напомним, что шквал анонимных звонков об угрозах взрыва в общественных местах в Москве и других городах России прошел в сентябре 2017 года.
# i= 1609
# Итоговый ответ: нет
# Исходный текст: Днем число "заминированных" ТЦ выросло до 14, а количество эвакуированных - до 6 тыс. человек. Напомним, что шквал анонимных звонков об угрозах взрыва в общественных местах в Москве и других городах России прошел в сентябре 2017 года.
# i= 1610
# Итоговый ответ: нет
# Исходный текст: Представители транспортного комплекса Москвы обратились к столичным автомобилистам с призывом отказаться от личного транспорта в условиях снегопада, передает ТАСС.
# i= 1611
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# ['Снегопад']
# Исходный текст: Представители транспортного комплекса Москвы обратились к столичным автомобилистам с призывом отказаться от личного транспорта в условиях снегопада, передает ТАСС.
# i= 1612
# Итоговый ответ: нет
# Исходный текст: Синоптики рассказали, какая погода ожидает жителей Москвы и области в воскресенье, 25 ноября. Как передает ресурс «Метеоновости», в предстоящие сутки столичный регион продолжит находиться под влиянием циклона, что обусловит облачную и относительно теплую погоду без существенных осадков.
# i= 1613
# Итоговый ответ: нет
# Исходный текст: Сегодня в Москве ожидается прохладная и облачная погода. Синоптики также прогнозируют порывистый ветер. Как сообщает РИА Новости со ссылкой на центр погоды "Фобос", погоду в регионе будет определять циклон с северо-востока.
# i= 1614
# Итоговый ответ: нет
# Исходный текст: Гидрометцентр России сообщил, что 24 ноября в Москве пройдёт небольшой снегопад, а столбики термометров опустятся до 2 градусов мороза. Об этом говорится на сайте метеослужбы. Согласно прогнозу, погода в российской столице будет облачной.
# i= 1615
# Итоговый ответ: нет
# Исходный текст: Температура воздуха опустится ниже нормы на 7 градусов и станет соответствовать показателям конца января. Как рассказали "РГ" в Метеобюро Москвы и области, южный циклон, который, вероятно, пройдет южнее Московского региона и не затронет его, пустит холод в столицу.
# i= 1616
# Итоговый ответ: нет
# Исходный текст: Ранее метеоролог напомнил москвичам-автомобилистам о необходимости заменить летнюю резину на зимнюю из-за возможного появления на дорогах гололедицы.
# i= 1617
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Гололедно-изморозевые явления
# Исходный текст: Научный руководитель Гидрометцентра России Роман Вильфанд заявил, что похолодание и легкие осадки в виде снега приведут к гололедице в Московском регионе, автомобилистам следует сменить летнюю резину на зимнюю.
# i= 1618
# Итоговый ответ: Да.
#
# Класс катаклизма: Гололедно-изморозевые явления.
# Исходный текст: Синоптики отмечают, что возможны образование гололедицы на дорогах и налипание мокрого снега, поэтому автомобилистам стоит быть предельно внимательными и аккуратными.
# i= 1619
# Итоговый ответ: нет
# Исходный текст: Автомобилистам советуют не выезжать на летней резине из-за снегопада, который обрушится на Москву в выходные, а также воспользоваться последним шансом заменить покрышки, говорится в сообщениях центра погоды "Фобос" и столичного Центра организации дорожного движения (ЦОДД).
# i= 1620
# Итоговый ответ: нет
# Исходный текст: Как сообщает агентство «Москва» со ссылкой на центр погоды «Фобос», в четверг москвичей ждет аномально высокое давление из-за влияния антициклона на погоду в столице.
# i= 1621
# Итоговый ответ: Да.
#
# Классы катаклизмов, упомянутые в тексте:
#
# * Сильные атмосферные осадки (снег)
# * Заморозки
# Исходный текст: В Москве автомобилистов из-за снегопада, который прошел в ночь 15 ноября, призвали быть осторожнее на дорогах.
# i= 1622
# Итоговый ответ: нет
# Исходный текст: Столбики термометров днём не поднимутся выше нуля градусов из-за накрывшего столицу арктического циклона.
# i= 1623
# Итоговый ответ: нет
# Исходный текст: В пятницу, 9 ноября, столичный регион будет находиться на юго-западной периферии антициклона, что обеспечит переменную облачность без осадков.
# i= 1624
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Заморозки
# * Наледеобразование
# Исходный текст: Выборочная противогололедная обработка дорог будет проведена на опасных участках дорог Москвы из-за ухудшения погоды, прогнозируемых ночных заморозков, осадков в виде мокрого снега и образования наледи, проинформировал заместитель мэра столицы по вопросам жилищно-коммунального хозяйства и благоустройства Петр Бирюков.
# i= 1625
# Итоговый ответ: нет
# Исходный текст: В понедельник, 29 октября, ненастный циклон покинет столичный регион. Об этом сообщает ИА «Метеоновости».
# i= 1626
# Итоговый ответ: Да, это новость о природном катаклизме.
#
# Классы катаклизмов, упомянутые в тексте:
#
# * Снегопад
# * Сильные атмосферные осадки
# Исходный текст: Снегопад, начавшийся в Москве вслед за дождями в субботу вечером, образовал в городе первый в этом сезоне снежный покров, сообщили РИА Новости в центре погоды "Фобос" в воскресенье.
# i= 1627
# Итоговый ответ: нет
# Исходный текст: Как сообщили в Гидрометцентре, в ближайшие часы в Москву придет циклон.
# i= 1628
# Итоговый ответ: нет
# Исходный текст: В ближайшие часы в Москву придет циклон, сопровождаемый дождями. Температура днем составит 7 градусов выше ноля, сообщает Гидрометцентр.
# i= 1629
# Итоговый ответ: нет
# Исходный текст: В среду, 24 октября, Московский регион окажется почти в самом «сердце» североатлантического циклона, наполненного «полчищами» дождевых туч.
# i= 1630
# Итоговый ответ: нет
# Исходный текст: В среду, 24 октября, циклон со стороны Балтийского моря принесет в столичный регион дожди, сообщает ИА «Метеоновости».
# i= 1631
# Итоговый ответ: Нет
# Исходный текст: Дневная температура остановилась на отметке плюс 17,9 градуса. Аномально теплую погоду в Москву принес азорский антициклон.
# i= 1632
# Итоговый ответ: нет
# Исходный текст: Антициклон вернет в столицу «бабе лето». Дневная температура воздуха может превысить +16, + 18 градусов.
# i= 1633
# Итоговый ответ: нет
# Исходный текст: Суббота, 6 октября, в столичном регионе пройдет под влиянием антициклона.
# i= 1634
# Итоговый ответ: нет
# Исходный текст: Московский регион 6 октября вошел под влияние северной периферии гребня антициклона.
# i= 1635
# Итоговый ответ: нет
# Исходный текст: Число арестованных в следственных изоляторах Москвы снизилось за два года до 9,7 тысячи человек, сообщил глава столичного управления ФСИН Сергей Мороз.
# i= 1636
# Итоговый ответ: нет
# Исходный текст: Число арестованных в следственных изоляторах Москвы снизилось за два года на 2 тысячи человек, а превышение нормативов по площади на одного арестованного ("перелимит") упало до 13%, сообщил РИА Новости начальник столичного управления ФСИН Сергей Мороз.
# i= 1637
# Итоговый ответ: нет
# Исходный текст: «Есть надежда на то, что к началу октября инициативу перехватит скандинавский антициклон, поэтому вполне возможна третья волна бабьего лета, но уже в прохладном исполнении», - сказал Тишковец РИА Новости.
# i= 1638
# Итоговый ответ: нет
# Исходный текст: Ранее МЧС распространило штормовое предупреждение о грозе, дожде и сильном ветре в Москве. Непогода сохранится до 22 часов.
# i= 1639
# Итоговый ответ: Да
#
# Классы катаклизмов:
#
# * Ураганы, смерчи, сильный ветер
# Исходный текст: В Московском регионе из-за шквалистого ветра до 17 метров в секунду объявлен «желтый» уровень погодной опасности на 24 часа с 21:00 субботы, 22 сентября, сообщили в Гидрометцентре.
# i= 1640
# Итоговый ответ: нет
# Исходный текст: С приходом антициклона теплый день с июльскими климатическими температурными показателями ждет москвичей.
# i= 1641
# Прошло времени 8183.6251838207245

# %%
results_df = pd.DataFrame({'text': texts, 'class': classes})
path_to_save = ''
results_df.to_csv(path_to_save)
df_cleaned = results_df.loc[~results_df['class'].isin(['нет', 'Нет',' нет','нет '])]

# %%
df_cleaned
# Out:
#                                                    text  \
# 7     Чеченскую Республику накрыли сильные ливни и ш...
# 8     В связи с продолжительными ливневыми осадками,...
# 10    Очередной борт с гуманитарной помощью для бедс...
# 42    Ассаламу алайкум! Прошедшей ночью в результате...
# 44    Дорогие друзья! По завершении заседания Операт...
# ...                                                 ...
# 1653  ШТОРМОВОЕ ПРЕДУПРЕЖДЕНИЕ   По сведениям Центра...
# 1655  По сведениям Калининградского центра по гидром...
# 1656  МЧС объявило штормовое предупреждение в Калини...
# 1660  Уважаемые жители и гости города Светлогорска! ...
# 1666  Внимание: штормовое предупреждение. Утром 3 ок...
#
#                                                   class
# 7     Да\n\nКлассы катаклизмов: \n\n* Сильные атмосф...
# 8     Да, это новость о природном катаклизме, включа...
# 10    Да,\n\nКлассы катаклизмов, упомянутые в тексте...
# 42    Да\n\nКлассы катаклизмов:\n\n* Наводнение\n* С...
# 44    да\n\nКлассы катаклизмов:\n\n- Сильные атмосфе...
# ...                                                 ...
# 1653  Да\n\nКлассы катаклизмов:\n\n* Сильные атмосфе...
# 1655  Да\n\nКлассы катаклизмов:\n\n* Ураганы, смерчи...
# 1656  Да, новость относится к категории предупрежден...
# 1660  Да, это относится к новости о природном катакл...
# 1666  Да\n\nКлассы катаклизмов: \n\n* Ураганы, смерч...
#
# [594 rows x 2 columns]

# %%
df_cleaned['Найденные ключевые слова'] = ""

def find_keywords(text):
  keywords_found = []
  for keyword in df_classes['Опасные природные процессы']:
    if keyword.lower() in text.lower():
      keywords_found.append(keyword)
  return ', '.join(keywords_found)

# Преобразование столбца 'class' к строкам
df_cleaned['class'] = df_cleaned['class'].astype(str)

# Применение функции к каждой строке в столбце 'class'
df_cleaned['class'] = df_cleaned['class'].apply(find_keywords)
df_cleaned = df_cleaned.dropna()
df_cleaned.to_csv('/content/drive/MyDrive/HSE_project/ЦФО/final_data/26072024_plan_minimum_Moscow.csv')
df_cleaned
# Out:
#                                       class  \
# 1                                 Заморозки
# 2                                 Заморозки
# 3             Гололедно-изморозевые явления
# 5             Гололедно-изморозевые явления
# 6                Сильные атмосферные осадки
# ...                                     ...
# 1622  Заморозки, Сильные атмосферные осадки
# 1625           Наледеобразование, Заморозки
# 1627             Сильные атмосферные осадки
# 1640         Ураганы, смерчи, сильный ветер
# 1642
#
#                                                  text_x  \
# 1     🥶 В ночь с 11 на 12 мая в столице ожидаются за...
# 2     ❗️В ночь на 5 апреля в Москве ожидаются заморо...
# 3     ❗️В Москве сегодня ночью ожидается гололедица....
# 5     🌧 С 18:00 в Москве ожидается ледяной дождь. На...
# 6     🌨 В субботу в Москве ожидается снегопад, котор...
# ...                                                 ...
# 1622  В Москве автомобилистов из-за снегопада, котор...
# 1625  Выборочная противогололедная обработка дорог б...
# 1627  Снегопад, начавшийся в Москве вслед за дождями...
# 1640  В Московском регионе из-за шквалистого ветра д...
# 1642  В понедельник, 17 сентября, усилится влияние а...
#
#                             ССЫЛКА НА ПОСТ НАЗВАНИЕ ВЛАДЕЛЬЦА  \
# 1     https://vk.com/wall-106849164_170339       Город Москва
# 2     https://vk.com/wall-106849164_167671       Город Москва
# 3     https://vk.com/wall-106849164_167003       Город Москва
# 5     https://vk.com/wall-106849164_165027       Город Москва
# 6     https://vk.com/wall-106849164_164558       Город Москва
# ...                                    ...                ...
# 1622    https://vk.com/wall-169705869_3642   Москва • Новости
# 1625    https://vk.com/wall-169705869_2847   Москва • Новости
# 1627    https://vk.com/wall-169705869_2782   Москва • Новости
# 1640     https://vk.com/wall-169705869_985   Москва • Новости
# 1642     https://vk.com/wall-169705869_708   Москва • Новости
#
#        ДАТА ПУБЛИКАЦИИ                                              ТЕКСТ  \
# 1     2024-05-11 14:25  🥶 В ночь с 11 на 12 мая в столице ожидаются за...
# 2     2024-04-04 12:30  ❗️В ночь на 5 апреля в Москве ожидаются заморо...
# 3     2024-03-25 16:40  ❗️В Москве сегодня ночью ожидается гололедица....
# 5     2024-02-25 14:23  🌧 С 18:00 в Москве ожидается ледяной дождь. На...
# 6     2024-02-17 17:04  🌨 В субботу в Москве ожидается снегопад, котор...
# ...                ...                                                ...
# 1622  2018-11-15 06:57  В Москве автомобилистов из-за снегопада, котор...
# 1625  2018-10-30 00:08  Выборочная противогололедная обработка дорог б...
# 1627  2018-10-28 12:04  Снегопад, начавшийся в Москве вслед за дождями...
# 1640  2018-09-22 16:26  В Московском регионе из-за шквалистого ветра д...
# 1642  2018-09-17 09:01  В понедельник, 17 сентября, усилится влияние а...
#
#      Найденные ключевые слова
# 1
# 2
# 3
# 5
# 6
# ...                       ...
# 1622
# 1625
# 1627
# 1640
# 1642
#
# [423 rows x 7 columns]

# %%
path_all_data = ''
df_all = pd.read_csv(path_all_data)

df_cleaned = df_cleaned.reset_index()

# Добавляем индекс к df2
df_all = df_all.reset_index()

# Объединяем таблицы по новому индексу
merged_df = pd.merge(df_cleaned, df_all, on='index', how='outer')

# Удаляем ненужный столбец 'index'
merged_df = merged_df.drop('index', axis=1)

merged_df = merged_df[['class','text_x','ССЫЛКА НА ПОСТ','НАЗВАНИЕ ВЛАДЕЛЬЦА','ДАТА ПУБЛИКАЦИИ','ТЕКСТ']]
merged_df
# Out:
#                                                   class  \
# 0                                                   нет
# 1              Да\n\nКлассы катаклизмов:\n\n* Заморозки
# 2     Да, это новость о природном катаклизме.\n\nКла...
# 3     Да\n\nКласс катаклизмов: Гололедно-изморозевые...
# 4                                                   нет
# ...                                                 ...
# 1638                                                нет
# 1639                                                нет
# 1640  Да\n\nКлассы катаклизмов:\n\n* Ураганы, смерчи...
# 1641                                                нет
# 1642                                                NaN
#
#                                                  text_x  \
# 0     🌧️ В ночь на 20 июня в Москве ухудшится погода...
# 1     🥶 В ночь с 11 на 12 мая в столице ожидаются за...
# 2     ❗️В ночь на 5 апреля в Москве ожидаются заморо...
# 3     ❗️В Москве сегодня ночью ожидается гололедица....
# 4     🏥 В Москве открылись первые детские эндоскопич...
# ...                                                 ...
# 1638  «Есть надежда на то, что к началу октября иниц...
# 1639  Ранее МЧС распространило штормовое предупрежде...
# 1640  В Московском регионе из-за шквалистого ветра д...
# 1641  С приходом антициклона теплый день с июльскими...
# 1642  В понедельник, 17 сентября, усилится влияние а...
#
#                             ССЫЛКА НА ПОСТ НАЗВАНИЕ ВЛАДЕЛЬЦА  \
# 0     https://vk.com/wall-106849164_172694       Город Москва
# 1     https://vk.com/wall-106849164_170339       Город Москва
# 2     https://vk.com/wall-106849164_167671       Город Москва
# 3     https://vk.com/wall-106849164_167003       Город Москва
# 4     https://vk.com/wall-106849164_166045       Город Москва
# ...                                    ...                ...
# 1638    https://vk.com/wall-169705869_1044   Москва • Новости
# 1639    https://vk.com/wall-169705869_1013   Москва • Новости
# 1640     https://vk.com/wall-169705869_985   Москва • Новости
# 1641     https://vk.com/wall-169705869_913   Москва • Новости
# 1642     https://vk.com/wall-169705869_708   Москва • Новости
#
#        ДАТА ПУБЛИКАЦИИ                                              ТЕКСТ
# 0     2024-06-19 12:30  🌧️ В ночь на 20 июня в Москве ухудшится погода...
# 1     2024-05-11 14:25  🥶 В ночь с 11 на 12 мая в столице ожидаются за...
# 2     2024-04-04 12:30  ❗️В ночь на 5 апреля в Москве ожидаются заморо...
# 3     2024-03-25 16:40  ❗️В Москве сегодня ночью ожидается гололедица....
# 4     2024-03-14 18:30  🏥 В Москве открылись первые детские эндоскопич...
# ...                ...                                                ...
# 1638  2018-09-24 03:43  «Есть надежда на то, что к началу октября иниц...
# 1639  2018-09-23 11:23  Ранее МЧС распространило штормовое предупрежде...
# 1640  2018-09-22 16:26  В Московском регионе из-за шквалистого ветра д...
# 1641  2018-09-21 10:35  С приходом антициклона теплый день с июльскими...
# 1642  2018-09-17 09:01  В понедельник, 17 сентября, усилится влияние а...
#
# [1643 rows x 6 columns]
